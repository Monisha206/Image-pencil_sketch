# %% [markdown]
# <a href="https://colab.research.google.com/github/Monisha206/Image-pencil_sketch/blob/main/image_to_pencil_sketch.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import cv2
from google.colab.patches import cv2_imshow

# %%
image = cv2.imread("/content/drive/MyDrive/Dataset/dog.jpg")
cv2_imshow( image)
cv2.waitKey(0)

# %%
gray_image = cv2.cvtColor(image, cv2.COLOR_BGR2GRAY)
cv2_imshow(gray_image)
cv2.waitKey(0)

# %%
inverted_image = 255 - gray_image
cv2_imshow(inverted_image)
cv2.waitKey()

# %%
blurred = cv2.GaussianBlur(inverted_image, (21, 21), 0)

# %%
inverted_blurred = 255 - blurred
pencil_sketch = cv2.divide(gray_image, inverted_blurred, scale=256.0)
cv2_imshow(pencil_sketch)
cv2.waitKey(0)
# Out:
# <PIL.Image.Image image mode=L size=5000x3333>
# -1

# %%
print("")
cv2_imshow(image)
cv2_imshow(pencil_sketch)
cv2.waitKey(0)
